# %% [markdown]
# # SpotipyIterator
#
# An idea for iterable interface I am developing as a contribution to the plamere/spotipy (a Spotify API client)
# repository on Github.

# %%
import re

import inflect
import json
from spotipy import Spotify
from spotipy.oauth2 import SpotifyClientCredentials


class SpotipyIterator:
    """Make an iterator to use with Spotify API results"""

    INFLECT = inflect.engine()
    SEARCH_REGEXP = re.compile('^https?://[^/]+/v1/search\\b')
    SEARCH_MAX_OFFSET = 1000

    def __init__(self, *args, **kwargs):
        self._client = None
        if kwargs:
            if 'client' in kwargs:
                self._client = kwargs['client']
                del kwargs['client']
        if not self._client:
            self._client = Spotify(auth_manager=SpotifyClientCredentials(), 
                                   requests_session=True)
        self._collection = None
        if kwargs:
            if 'collection' in kwargs:
                self._collection = kwargs['collection']
                del kwargs['collection']
            else:
                if 'type' in kwargs:
                    self._collection = self.INFLECT.plural(kwargs['type'])
        result, *args = args
        if callable(result):
            result = result(self._client, *args, **kwargs)
        if result and 'total' not in result:
            if not self._collection:
                self._collection, *_ = result.keys()
        self._prepare_next_page(result)

    def __iter__(self):
        return self

    def __next__(self):
        if self._row >= self._page_size:
            if self._page and 'next' in self._page and self._page['next']:
                if self.SEARCH_REGEXP.match(self._page['next']):
                    if self._page['offset'] + self._page['limit'] >= self.SEARCH_MAX_OFFSET:
                        raise StopIteration
                self._prepare_next_page(self._client.next(self._page))
                if self._row >= self._page_size:
                    raise StopIteration
            else:
                raise StopIteration
        this_row = self._row
        self._row = this_row + 1
        return self._page['items'][this_row]

    def _prepare_next_page(self, result):
        if self._collection:
            self._page = result[self._collection]
        else:
            self._page = result
        self._page_size = 0
        if self._page and 'items' in self._page:
            self._page_size = len(self._page['items'])
        self._row = 0
        return self

# %%
import json
from spotipy import Spotify
from spotipy.oauth2 import SpotifyClientCredentials

# Create a spotipy.Spotify API client...
sp = Spotify(auth_manager=SpotifyClientCredentials(),
            requests_session=True)
# Have the client search for artists within the prog rock genre, whose
# name contains "Rush"...
name, genre = ('Rush', 'progressive rock')
search = sp.search(f'artist:"{name}" genre:"{genre}"',
                   type='artist')
# Create an iterator from the search results. Unlike other end-points, a
# search organises data into subcollections whose keys will be the plural
# of the type(s) of data requested. So, for searches, we can specify which
# collection of data over which to iterate...
artists = SpotipyIterator(search, collection='artists', client=sp)
print(json.dumps([*artists], indent=True))
# Out:
# [
#  {
#   "external_urls": {
#    "spotify": "https://open.spotify.com/artist/2Hkut4rAAyrQxRdof7FVJq"
#   },
#   "followers": {
#    "href": null,
#    "total": 1849016
#   },
#   "genres": [
#    "album rock",
#    "art rock",
#    "canadian metal",
#    "classic canadian rock",
#    "classic rock",
#    "hard rock",
#    "metal",
#    "progressive rock",
#    "rock"
#   ],
#   "href": "https://api.spotify.com/v1/artists/2Hkut4rAAyrQxRdof7FVJq",
#   "id": "2Hkut4rAAyrQxRdof7FVJq",
#   "images": [
#    {
#     "height": 640,
#     "url": "https://i.scdn.co/image/ab6761610000e5eb896c4b043fb3063178afd716",
#     "width": 640
#    },
#    {
#     "height": 320,
#     "url": "https://i.scdn.co/image/ab67616100005174896c4b043fb3063178afd716",
#     "width": 320
#    },
#    {
#     "height": 160,
#     "url": "https://i.scdn.co/image/ab6761610000f178896c4b043fb3063178afd716",
#     "width": 160
#    }
#   ],
#   "name": "Rush",
#   "popularity": 70,
#   "type": "artist",
#   "uri": "spotify:artist:2Hkut4rAAyrQxRdof7FVJq"
#  }
# ]

# %%
# For searches, we may use 'type' (expressed in singular form) to
# identify the type of data over which to iterate. This should be the
# same as the 'type' specified in the call to the search method.
artists = SpotipyIterator(search, type='artist', client=sp)
print(json.dumps([*artists], indent=True))
# Out:
# [
#  {
#   "external_urls": {
#    "spotify": "https://open.spotify.com/artist/2Hkut4rAAyrQxRdof7FVJq"
#   },
#   "followers": {
#    "href": null,
#    "total": 1849016
#   },
#   "genres": [
#    "album rock",
#    "art rock",
#    "canadian metal",
#    "classic canadian rock",
#    "classic rock",
#    "hard rock",
#    "metal",
#    "progressive rock",
#    "rock"
#   ],
#   "href": "https://api.spotify.com/v1/artists/2Hkut4rAAyrQxRdof7FVJq",
#   "id": "2Hkut4rAAyrQxRdof7FVJq",
#   "images": [
#    {
#     "height": 640,
#     "url": "https://i.scdn.co/image/ab6761610000e5eb896c4b043fb3063178afd716",
#     "width": 640
#    },
#    {
#     "height": 320,
#     "url": "https://i.scdn.co/image/ab67616100005174896c4b043fb3063178afd716",
#     "width": 320
#    },
#    {
#     "height": 160,
#     "url": "https://i.scdn.co/image/ab6761610000f178896c4b043fb3063178afd716",
#     "width": 160
#    }
#   ],
#   "name": "Rush",
#   "popularity": 70,
#   "type": "artist",
#   "uri": "spotify:artist:2Hkut4rAAyrQxRdof7FVJq"
#  }
# ]

# %%
# But the iterator is also smart enough to the first collection it
# finds for a search result. So you can also be lazy...
artists = SpotipyIterator(search, client=sp)
print(json.dumps([*artists], indent=True))
# Out:
# [
#  {
#   "external_urls": {
#    "spotify": "https://open.spotify.com/artist/2Hkut4rAAyrQxRdof7FVJq"
#   },
#   "followers": {
#    "href": null,
#    "total": 1849016
#   },
#   "genres": [
#    "album rock",
#    "art rock",
#    "canadian metal",
#    "classic canadian rock",
#    "classic rock",
#    "hard rock",
#    "metal",
#    "progressive rock",
#    "rock"
#   ],
#   "href": "https://api.spotify.com/v1/artists/2Hkut4rAAyrQxRdof7FVJq",
#   "id": "2Hkut4rAAyrQxRdof7FVJq",
#   "images": [
#    {
#     "height": 640,
#     "url": "https://i.scdn.co/image/ab6761610000e5eb896c4b043fb3063178afd716",
#     "width": 640
#    },
#    {
#     "height": 320,
#     "url": "https://i.scdn.co/image/ab67616100005174896c4b043fb3063178afd716",
#     "width": 320
#    },
#    {
#     "height": 160,
#     "url": "https://i.scdn.co/image/ab6761610000f178896c4b043fb3063178afd716",
#     "width": 160
#    }
#   ],
#   "name": "Rush",
#   "popularity": 70,
#   "type": "artist",
#   "uri": "spotify:artist:2Hkut4rAAyrQxRdof7FVJq"
#  }
# ]

# %%
# In fact, if you don't provide a 'client', the iterator will create
# and use it's own, allowing laziness to be taken to a new level...
artists = SpotipyIterator(sp.search(f'artist:"{name}" genre:"{genre}"',
                                    type='artist'))
print(json.dumps([*artists], indent=True))
# Out:
# [
#  {
#   "external_urls": {
#    "spotify": "https://open.spotify.com/artist/2Hkut4rAAyrQxRdof7FVJq"
#   },
#   "followers": {
#    "href": null,
#    "total": 1849016
#   },
#   "genres": [
#    "album rock",
#    "art rock",
#    "canadian metal",
#    "classic canadian rock",
#    "classic rock",
#    "hard rock",
#    "metal",
#    "progressive rock",
#    "rock"
#   ],
#   "href": "https://api.spotify.com/v1/artists/2Hkut4rAAyrQxRdof7FVJq",
#   "id": "2Hkut4rAAyrQxRdof7FVJq",
#   "images": [
#    {
#     "height": 640,
#     "url": "https://i.scdn.co/image/ab6761610000e5eb896c4b043fb3063178afd716",
#     "width": 640
#    },
#    {
#     "height": 320,
#     "url": "https://i.scdn.co/image/ab67616100005174896c4b043fb3063178afd716",
#     "width": 320
#    },
#    {
#     "height": 160,
#     "url": "https://i.scdn.co/image/ab6761610000f178896c4b043fb3063178afd716",
#     "width": 160
#    }
#   ],
#   "name": "Rush",
#   "popularity": 70,
#   "type": "artist",
#   "uri": "spotify:artist:2Hkut4rAAyrQxRdof7FVJq"
#  }
# ]

# %%
# ... but, this isn't ideal because, using the example above, we created
# and used our own instance of the spotipy.Spotify API client to get the
# first page of search results, but the iterator had to create another
# to fetch any remaining results. 
#
# There is another way to use the iterator that eliminates this kind of
# waste. Instead of passing the first page of results, you may pass a 
# function and follow it with the arguments that the iterator can pass
# to it when it is called. The iterator will then create and use the same
# client for all pages of results. You can still pass in your own client
# if you need to create it a specific way, but you don't need to.
#
# A side-benefit here, in the case of Spotify.search, is that the iterator
# is able to infer the 'type' of data being iterated over from the list of
# arguments passed to the function it will call. There is no requirement
# to specify the 'type' again...
artists = SpotipyIterator(Spotify.search,
                          f'artist:"{name}" genre:"{genre}"',
                          type='artist')
print(json.dumps([*artists], indent=True))
# Out:
# [
#  {
#   "external_urls": {
#    "spotify": "https://open.spotify.com/artist/2Hkut4rAAyrQxRdof7FVJq"
#   },
#   "followers": {
#    "href": null,
#    "total": 1849016
#   },
#   "genres": [
#    "album rock",
#    "art rock",
#    "canadian metal",
#    "classic canadian rock",
#    "classic rock",
#    "hard rock",
#    "metal",
#    "progressive rock",
#    "rock"
#   ],
#   "href": "https://api.spotify.com/v1/artists/2Hkut4rAAyrQxRdof7FVJq",
#   "id": "2Hkut4rAAyrQxRdof7FVJq",
#   "images": [
#    {
#     "height": 640,
#     "url": "https://i.scdn.co/image/ab6761610000e5eb896c4b043fb3063178afd716",
#     "width": 640
#    },
#    {
#     "height": 320,
#     "url": "https://i.scdn.co/image/ab67616100005174896c4b043fb3063178afd716",
#     "width": 320
#    },
#    {
#     "height": 160,
#     "url": "https://i.scdn.co/image/ab6761610000f178896c4b043fb3063178afd716",
#     "width": 160
#    }
#   ],
#   "name": "Rush",
#   "popularity": 70,
#   "type": "artist",
#   "uri": "spotify:artist:2Hkut4rAAyrQxRdof7FVJq"
#  }
# ]

# %%
# Every example so far has yielded a single result, but we can 
# make the genre a little more broad to show multiple results...
artists = SpotipyIterator(Spotify.search,
                          f'artist:"{name}" genre:"rock"',
                          type='artist')
print(json.dumps([*artists], indent=True))
# Out:
# [
#  {
#   "external_urls": {
#    "spotify": "https://open.spotify.com/artist/2Hkut4rAAyrQxRdof7FVJq"
#   },
#   "followers": {
#    "href": null,
#    "total": 1849016
#   },
#   "genres": [
#    "album rock",
#    "art rock",
#    "canadian metal",
#    "classic canadian rock",
#    "classic rock",
#    "hard rock",
#    "metal",
#    "progressive rock",
#    "rock"
#   ],
#   "href": "https://api.spotify.com/v1/artists/2Hkut4rAAyrQxRdof7FVJq",
#   "id": "2Hkut4rAAyrQxRdof7FVJq",
#   "images": [
#    {
#     "height": 640,
#     "url": "https://i.scdn.co/image/ab6761610000e5eb896c4b043fb3063178afd716",
#     "width": 640
#    },
#    {
#     "height": 320,
#     "url": "https://i.scdn.co/image/ab67616100005174896c4b043fb3063178afd716",
#     "width": 320
#    },
#    {
#     "height": 160,
#     "url": "https://i.scdn.co/image/ab6761610000f178896c4b043fb3063178afd716",
#     "width": 160
#    }
#   ],
#   "name": "Rush",
#   "popularity": 70,
#   "type": "artist",
#   "uri": "spotify:artist:2Hkut4rAAyrQxRdof7FVJq"
#  },
#  {
#   "external_urls": {
#    "spotify": "https://open.spotify.com/artist/1h0hOL3bVcYlg4xcSjU7fP"
#   },
#   "followers": {
#    "href": null,
#    "total": 153025
#   },
#   "genres": [
#    "blues",
#    "blues rock",
#    "chicago blues",
#    "electric blues",
#    "modern blues",
#    "traditional blues"
#   ],
#   "href": "https://api.spotify.com/v1/artists/1h0hOL3bVcYlg4xcSjU7fP",
#   "id": "1h0hOL3bVcYlg4xcSjU7fP",
#   "images": [
#    {
#     "height": 1388,
#     "url": "https://i.scdn.co/image/db7dfc09f445483d6771cf1f3c4d863af964ceaf",
#     "width": 1000
#    },
#    {
#     "height": 888,
#     "url": "https://i.scdn.co/image/aaa02988fa611e0b2113e537ad88a509bab2ecf4",
#     "width": 640
#    },
#    {
#     "height": 278,
#     "url": "https://i.scdn.co/image/c6fe59f94a05fe14029825e4af050ec36b0dbc3b",
#     "width": 200
#    },
#    {
#     "height": 89,
#     "url": "https://i.scdn.co/image/53d8ff84da1cd900e1b7b2838a9fd5777f7fa012",
#     "width": 64
#    }
#   ],
#   "name": "Otis Rush",
#   "popularity": 48,
#   "type": "artist",
#   "uri": "spotify:artist:1h0hOL3bVcYlg4xcSjU7fP"
#  },
#  {
#   "external_urls": {
#    "spotify": "https://open.spotify.com/artist/6vI5AwXkw8IFD7zsw6NkTp"
#   },
#   "followers": {
#    "href": null,
#    "total": 22382
#   },
#   "genres": [
#    "american folk revival",
#    "country rock",
#    "folk",
#    "folk rock",
#    "roots rock",
#    "singer-songwriter"
#   ],
#   "href": "https://api.spotify.com/v1/artists/6vI5AwXkw8IFD7zsw6NkTp",
#   "id": "6vI5AwXkw8IFD7zsw6NkTp",
#   "images": [
#    {
#     "height": 636,
#     "url": "https://i.scdn.co/image/eeebdaad3cf2067fb99e9c1a454c4589731ed5e0",
#     "width": 1000
#    },
#    {
#     "height": 407,
#     "url": "https://i.scdn.co/image/1b7d3505f6d79e7dd1fbb86f009993cec267f50c",
#     "width": 640
#    },
#    {
#     "height": 127,
#     "url": "https://i.scdn.co/image/5a915247cf3205e414d8e39d28bf3504877c3772",
#     "width": 200
#    },
#    {
#     "height": 41,
#     "url": "https://i.scdn.co/image/054d271726d84ee29c95c264bea908b13808e5b7",
#     "width": 64
#    }
#   ],
#   "name": "Tom Rush",
#   "popularity": 39,
#   "type": "artist",
#   "uri": "spotify:artist:6vI5AwXkw8IFD7zsw6NkTp"
#  },
#  {
#   "external_urls": {
#    "spotify": "https://open.spotify.com/artist/4KQZcyr3Dn3NEr5Qu7dxuc"
#   },
#   "followers": {
#    "href": null,
#    "total": 39578
#   },
#   "genres": [
#    "ccm",
#    "christian alternative rock",
#    "christian music",
#    "worship"
#   ],
#   "href": "https://api.spotify.com/v1/artists/4KQZcyr3Dn3NEr5Qu7dxuc",
#   "id": "4KQZcyr3Dn3NEr5Qu7dxuc",
#   "images": [
#    {
#     "height": 640,
#     "url": "https://i.scdn.co/image/ab6761610000e5eb4497ea9e99f5acd0f43e23f0",
#     "width": 640
#    },
#    {
#     "height": 320,
#     "url": "https://i.scdn.co/image/ab676161000051744497ea9e99f5acd0f43e23f0",
#     "width": 320
#    },
#    {
#     "height": 160,
#     "url": "https://i.scdn.co/image/ab6761610000f1784497ea9e99f5acd0f43e23f0",
#     "width": 160
#    }
#   ],
#   "name": "Rush Of Fools",
#   "popularity": 32,
#   "type": "artist",
#   "uri": "spotify:artist:4KQZcyr3Dn3NEr5Qu7dxuc"
#  },
#  {
#   "external_urls": {
#    "spotify": "https://open.spotify.com/artist/6803XTpoywjl9e37yTvwt7"
#   },
#   "followers": {
#    "href": null,
#    "total": 25102
#   },
#   "genres": [
#    "blues rock",
#    "canadian metal"
#   ],
#   "href": "https://api.spotify.com/v1/artists/6803XTpoywjl9e37yTvwt7",
#   "id": "6803XTpoywjl9e37yTvwt7",
#   "images": [
#    {
#     "height": 640,
#     "url": "https://i.scdn.co/image/ab67616d0000b273bef76218c65153abaed75e6e",
#     "width": 640
#    },
#    {
#     "height": 300,
#     "url": "https://i.scdn.co/image/ab67616d00001e02bef76218c65153abaed75e6e",
#     "width": 300
#    },
#    {
#     "height": 64,
#     "url": "https://i.scdn.co/image/ab67616d00004851bef76218c65153abaed75e6e",
#     "width": 64
#    }
#   ],
#   "name": "Frank Marino & Mahogany Rush",
#   "popularity": 33,
#   "type": "artist",
#   "uri": "spotify:artist:6803XTpoywjl9e37yTvwt7"
#  },
#  {
#   "external_urls": {
#    "spotify": "https://open.spotify.com/artist/0M12q0sYgM4yYWBAf7rqME"
#   },
#   "followers": {
#    "href": null,
#    "total": 25242
#   },
#   "genres": [
#    "pakistani indie",
#    "pakistani rock"
#   ],
#   "href": "https://api.spotify.com/v1/artists/0M12q0sYgM4yYWBAf7rqME",
#   "id": "0M12q0sYgM4yYWBAf7rqME",
#   "images": [
#    {
#     "height": 640,
#     "url": "https://i.scdn.co/image/ab6761610000e5eb50e4efd0d38650f7caf63efc",
#     "width": 640
#    },
#    {
#     "height": 320,
#     "url": "https://i.scdn.co/image/ab6761610000517450e4efd0d38650f7caf63efc",
#     "width": 320
#    },
#    {
#     "height": 160,
#     "url": "https://i.scdn.co/image/ab6761610000f17850e4efd0d38650f7caf63efc",
#     "width": 160
#    }
#   ],
#   "name": "Rushk",
#   "popularity": 22,
#   "type": "artist",
#   "uri": "spotify:artist:0M12q0sYgM4yYWBAf7rqME"
#  },
#  {
#   "external_urls": {
#    "spotify": "https://open.spotify.com/artist/3oydpSZWTtiIvhUtmMk3be"
#   },
#   "followers": {
#    "href": null,
#    "total": 428
#   },
#   "genres": [
#    "psychedelic blues-rock"
#   ],
#   "href": "https://api.spotify.com/v1/artists/3oydpSZWTtiIvhUtmMk3be",
#   "id": "3oydpSZWTtiIvhUtmMk3be",
#   "images": [
#    {
#     "height": 640,
#     "url": "https://i.scdn.co/image/ab67616d0000b273a85c567d6a5eb8bd20d072c4",
#     "width": 640
#    },
#    {
#     "height": 300,
#     "url": "https://i.scdn.co/image/ab67616d00001e02a85c567d6a5eb8bd20d072c4",
#     "width": 300
#    },
#    {
#     "height": 64,
#     "url": "https://i.scdn.co/image/ab67616d00004851a85c567d6a5eb8bd20d072c4",
#     "width": 64
#    }
#   ],
#   "name": "Mount Rushmore",
#   "popularity": 8,
#   "type": "artist",
#   "uri": "spotify:artist:3oydpSZWTtiIvhUtmMk3be"
#  },
#  {
#   "external_urls": {
#    "spotify": "https://open.spotify.com/artist/24ZRL2hX0dY97pP51BxlSf"
#   },
#   "followers": {
#    "href": null,
#    "total": 1694
#   },
#   "genres": [
#    "swedish melodic rock"
#   ],
#   "href": "https://api.spotify.com/v1/artists/24ZRL2hX0dY97pP51BxlSf",
#   "id": "24ZRL2hX0dY97pP51BxlSf",
#   "images": [
#    {
#     "height": 640,
#     "url": "https://i.scdn.co/image/ab6761610000e5ebb655e2a9a9a6f075ed912737",
#     "width": 640
#    },
#    {
#     "height": 320,
#     "url": "https://i.scdn.co/image/ab67616100005174b655e2a9a9a6f075ed912737",
#     "width": 320
#    },
#    {
#     "height": 160,
#     "url": "https://i.scdn.co/image/ab6761610000f178b655e2a9a9a6f075ed912737",
#     "width": 160
#    }
#   ],
#   "name": "Adrenaline Rush",
#   "popularity": 8,
#   "type": "artist",
#   "uri": "spotify:artist:24ZRL2hX0dY97pP51BxlSf"
#  }
# ]

# %%
from more_itertools import first_true

# Let's do a bit more with the API and with the SpotifyIterator,
# by listing names of albums released by the artist...
artists = SpotipyIterator(Spotify.search,
                          f'artist:"{name}" genre:"rock"',
                          type='artist')
artist = first_true(artists, None,
                    lambda x: name == x['name'] and 
                              genre in x['genres'])
albums = SpotipyIterator(Spotify.artist_albums,
                         artist['uri'],
                         album_type='album',
                         country='GB')
# TODO There is a problem, here...
#      We are not getting all items from the artist_albums
#      end-point. Suspect there's a snafu with the processing
#      of subsequent pages of results for non-search end-points.
#
album_names = [ 
    x['name'] for x in albums 
                    if '(' not in x['name'] and 
                       'Live' not in x['name']
]
print(json.dumps(album_names, indent=True))
# print(json.dumps([*albums], indent=True))
# Out:
# [
#  "Clockwork Angels Tour",
#  "Clockwork Angels",
#  "Snakes & Arrows",
#  "R30",
#  "Feedback",
#  "Different Stages",
#  "Presto",
#  "A Show Of Hands",
#  "Hold Your Fire",
#  "Power Windows",
#  "Grace Under Pressure",
#  "Signals",
#  "Exit ... Stage Left",
#  "Permanent Waves",
#  "Hemispheres",
#  "A Farewell To Kings",
#  "All The World's A Stage",
#  "2112",
#  "Caress Of Steel",
#  "Fly By Night",
#  "Rush",
#  "The First Us Tours"
# ]
